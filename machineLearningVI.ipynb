# %% [markdown]
# ## Chapter VI. Intro machine learning

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
x = np.random.uniform(0.0,5.0,25000)
plt.hist(x)
plt.show()

# %%
x = np.random.normal(0.0,5.0,250)
plt.hist(x)
plt.show()

# %%
x = np.random.uniform(0.0,5.0,250)
y = np
plt.hist(x)
plt.show()

# %%
x = [12,23,45,65,32,67,97,45]
y = [90,88,87,76,65,54,52,43]
slope , intercept, r,p,std_err = stats.linregress(x,y)

# %%
print(slope)
print(intercept)
print(r)
print(p)
print(std_err)
# Out:
# -0.4084929939948527
# 89.08478696025165
# -0.6064583565028687
# 0.11094001623727004
# 0.21864426283215388
