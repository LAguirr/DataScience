# %% [markdown]
# ### Data Manipulation

# %%
import pandas as pd
import numpy as np

# %%
frame1 = pd.DataFrame({'id':['ball','pencil','pen','mug','ashtray'], 'price': [12.33, 11.44, 33.21, 13.23, 33.62]})

# %%
frame2 = pd.DataFrame({'id':['pencil','pencil','ball','pen'], 'color':['white','red','red','black']})

# %%
result = pd.merge(frame1, frame2)
print(result)
# Out:
#        id  price  color
# 0    ball  12.33    red
# 1  pencil  11.44  white
# 2  pencil  11.44    red
# 3     pen  33.21  black

# %%
df1 = pd.DataFrame({
    "id":['ball','pencil','pen','mug','ashtray'],
    "color":['white','red','red','black','green'],
    "brand":['OMG','ABC','ABC','POD','POD']
})

df2 = pd.DataFrame({
    "id":['pencil','pencil','ball','pen'],
    "brand":['OMG','POD','ABC','POD']
})

# %%
print(pd.merge(df1,df2, on='id',how='left'))
# Out:
#         id  color brand_x brand_y
# 0     ball  white     OMG     ABC
# 1   pencil    red     ABC     OMG
# 2   pencil    red     ABC     POD
# 3      pen    red     ABC     POD
# 4      mug  black     POD     NaN
# 5  ashtray  green     POD     NaN

# %%
print(pd.merge(df1,df2, on='id',how='right'))
# Out:
#        id  color brand_x brand_y
# 0  pencil    red     ABC     OMG
# 1  pencil    red     ABC     POD
# 2    ball  white     OMG     ABC
# 3     pen    red     ABC     POD

# %% [markdown]
# ### Data Cleaning

# %%
df = pd.read_csv('dirtydata.csv')
df['Date'][26] = "'2020/12/26'"
df.head()

# %%
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
#df.dropna(subset=['Date','Calories'],inplace=True)
"""
for d in df.index
    if df.loc[d,"Duration"] > 120
        df.loc[d,"Duration"] = 120
        
"""

#drop_duplicates()

df.drop_duplicates(inplace=True)
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# ...

# %% [markdown]
# #### Correlation

# %%
df = pd.read_csv('data_workout.csv')
print(df.head())
df.corr()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %%
D = np.random.randint(10, 250, size = 20000)
P = np.random.randint(80, 140, size = 20000)
MP = np.random.randint(120, 160, size = 20000)
C = D*np.random.randint(5, 7, size = 20000)
dict= {'Duration': D, 'Pulse':P, 'Max Pulse':MP, 'Calories':C}
dataframe= pd.DataFrame(dict)
print(dataframe)
dataframe.to_csv("workout_20000.csv")
# Out:
#        Duration  Pulse  Max Pulse  Calories
# 0            85     91        123       510
# 1            84     84        152       504
# 2           248    110        130      1488
# 3            29    135        126       145
# 4           131    109        130       655
# ...         ...    ...        ...       ...
# 19995       203     90        139      1218
# 19996       173     87        126      1038
# 19997       238    131        139      1190
# 19998       216    122        133      1080
# 19999        16     93        143        80
#
# [20000 rows x 4 columns]

# %%
df = pd.DataFrame({'color':['white','red','green','red','green'],
                   'objet':['pen','pencil','pencil','ashtray','pen'],
                   'price1':[5.56,4.56,2.35,23.6,23.34],
                   'price2':[34.34,34.56,3.45,34.3,3.5]})

# %%
price_groupby_color = df['price1'].groupby(df['color'])
print(price_groupby_color.groups)
# Out:
# {'green': [2, 4], 'red': [1, 3], 'white': [0]}

# %%
print(price_groupby_color.mean())
# Out:
# color
# green    12.845
# red      14.080
# white     5.560
# Name: price1, dtype: float64
